# %%
import sys
import os

# Add the project root directory to sys.path
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '../..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../src')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../scripts')))

import pandas as pd
from eda.headline_analysis import HeadlineAnalysis
from eda.sentiment_analysis import SentimentAnalysis
from eda.time_series_analysis import TimeSeriesAnalysis
from data_cleaner import DataCleaner

# %%
#data = pd.read_csv('../data/raw_analyst_ratings.csv')
# data_subset = data.head(20)
df = pd.read_csv('../data/raw_analyst_ratings.csv')

# %%
# df = pd.read_csv('../data/raw_analyst_ratings.csv')

# DataCleaner(df)
# 
# Initialize the DataCleaner with the DataFrame
cleaner = DataCleaner(df)

# Clean the dates
cleaned_data = cleaner.clean_dates()
print(cleaned_data)


# Display the cleaned DataFrame
# cleaned_data.head(20)
# Out:
# okayssss
#          Unnamed: 0                                           headline  \
# 0                 0            Stocks That Hit 52-Week Highs On Friday
# 1                 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# ...             ...                                                ...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407324     1413845  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325     1413846  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326     1413847  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2        https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4        https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                    ...                ...
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...      Monica Gerson
# 1407324  https://www.benzinga.com/news/earnings/11/06/1...       Benjamin Lee
# 1407325  https://www.benzinga.com/analyst-ratings/analy...     BenzingaStaffL
# 1407326  https://www.benzinga.com/analyst-ratings/price...          Joe Young
# 1407327  https://www.benzinga.com/news/ipos/11/05/10789...      Allie Wickman
#
#                date stock
# 0        2020-06-05     A
# 1        2020-06-03     A
# 2        2020-05-26     A
# 3        2020-05-22     A
# 4        2020-05-22     A
# ...             ...   ...
# 1407323  2011-08-29    ZX
# 1407324  2011-06-22    ZX
# 1407325  2011-06-21    ZX
# 1407326  2011-06-21    ZX
# 1407327  2011-05-12    ZX
#
# [1407328 rows x 6 columns]

# %%
cleaned_data.head(20)
# Out:
#     Unnamed: 0                                           headline  \
# 0            0            Stocks That Hit 52-Week Highs On Friday
# 1            1         Stocks That Hit 52-Week Highs On Wednesday
# 2            2                      71 Biggest Movers From Friday
# 3            3       46 Stocks Moving In Friday's Mid-Day Session
# 4            4  B of A Securities Maintains Neutral on Agilent...
# 5            5  CFRA Maintains Hold on Agilent Technologies, L...
# 6            6  UBS Maintains Neutral on Agilent Technologies,...
# 7            7  Agilent Technologies shares are trading higher...
# 8            8  Wells Fargo Maintains Overweight on Agilent Te...
# 9            9         10 Biggest Price Target Changes For Friday
# 10          10    30 Stocks Moving in Friday's Pre-Market Session
# 11          11  SVB Leerink Maintains Outperform on Agilent Te...
# 12          12  8 Stocks Moving In Thursday's After-Hours Session
# 13          13  Agilent Technologies shares are trading higher...
# 14          14  Agilent Technologies Q2 Adj. EPS $0.71 Beats $...
# 15          15                Earnings Scheduled For May 21, 2020
# 16          16  Agilent Technologies Receives FDA Approval for...
# 17          17  Q1 13F Roundup: How Buffett, Einhorn, Ackman A...
# 18          18  Pershing Square 13F Shows Fund Raises Stake In...
# 19          19  How Bill Ackman Successfully Navigated Coronav...
#
#                                                   url  \
# 0   https://www.benzinga.com/news/20/06/16190091/s...
# 1   https://www.benzinga.com/news/20/06/16170189/s...
# 2   https://www.benzinga.com/news/20/05/16103463/7...
# 3   https://www.benzinga.com/news/20/05/16095921/4...
# 4   https://www.benzinga.com/news/20/05/16095304/b...
# 5   https://www.benzinga.com/news/20/05/16095163/c...
# 6   https://www.benzinga.com/news/20/05/16094027/u...
# 7   https://www.benzinga.com/wiim/20/05/16093805/a...
# 8   https://www.benzinga.com/news/20/05/16093505/w...
# 9   https://www.benzinga.com/analyst-ratings/price...
# 10  https://www.benzinga.com/news/20/05/16092879/3...
# 11  https://www.benzinga.com/news/20/05/16092270/s...
# 12  https://www.benzinga.com/news/20/05/16089803/8...
# 13  https://www.benzinga.com/wiim/20/05/16089218/a...
# 14  https://www.benzinga.com/news/earnings/20/05/1...
# 15  https://www.benzinga.com/news/earnings/20/05/1...
# 16  https://www.benzinga.com/news/20/05/16054223/a...
# 17  https://www.benzinga.com/news/20/05/16051311/q...
# 18  https://www.benzinga.com/general/hedge-funds/2...
# 19  https://www.benzinga.com/general/education/20/...
#
#                   publisher        date stock
# 0         Benzinga Insights  2020-06-05     A
# 1         Benzinga Insights  2020-06-03     A
# 2                Lisa Levin  2020-05-26     A
# 3                Lisa Levin  2020-05-22     A
# 4                Vick Meyer  2020-05-22     A
# 5   vishwanath@benzinga.com  2020-05-22     A
# 6   vishwanath@benzinga.com  2020-05-22     A
# 7         Benzinga Newsdesk  2020-05-22     A
# 8   vishwanath@benzinga.com  2020-05-22     A
# 9                Lisa Levin  2020-05-22     A
# 10               Lisa Levin  2020-05-22     A
# 11  vishwanath@benzinga.com  2020-05-22     A
# 12             Tyree Gorges  2020-05-21     A
# 13        Benzinga Newsdesk  2020-05-21     A
# 14        Benzinga Newsdesk  2020-05-21     A
# 15               Lisa Levin  2020-05-21     A
# 16            Luke J Jacobi  2020-05-18     A
# 17             Wayne Duggan  2020-05-16     A
# 18        Benzinga Newsdesk  2020-05-15     A
# 19             Wayne Duggan  2020-05-08     A

# %%
# Perform Headline Analysis
headline_analyzer = HeadlineAnalysis(cleaned_data)
print("Headline Length Stats:")
print(headline_analyzer.analyze_headline_length())
print("\nArticles per Publisher:")
print(headline_analyzer.count_articles_per_publisher())
print("\nPublication Date Trends:")
print(headline_analyzer.analyze_publication_dates())
# Out:
# Headline Length Stats:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64
#
# Articles per Publisher:
# /mnt/d/tutorial/10x/tasks/task_1/financial-news-stock-analysis/src/eda/headline_analysis.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=publisher_counts.index, y=publisher_counts.values, palette='viridis')
# Paul Quintaro                 228373
# Lisa Levin                    186979
# Benzinga Newsdesk             150484
# Charles Gross                  96732
# Monica Gerson                  82380
#                                ...
# David Wenger                       1
# Holly Huber - CrowdStreet          1
# Ryan Smith                         1
# vic@forextraininggroup.com         1
# official@stockmetrix.net           1
# Name: publisher, Length: 1034, dtype: int64
#
# Publication Date Trends:
# 2009-02-14      1
# 2009-04-27      2
# 2009-04-29      1
# 2009-05-22      1
# 2009-05-27      6
#              ...
# 2020-06-07     25
# 2020-06-08    765
# 2020-06-09    803
# 2020-06-10    807
# 2020-06-11    544
# Name: date, Length: 3955, dtype: int64

# %%
# Perform Sentiment Analysis
sentiment_analyzer = SentimentAnalysis(cleaned_data)
print("\nSentiment Summary:")
print(sentiment_analyzer.perform_sentiment_analysis())
print("\nCommon Keywords:")
print(sentiment_analyzer.extract_common_keywords())
# Out:
# Sentiment Summary:
# /mnt/d/tutorial/10x/tasks/task_1/financial-news-stock-analysis/src/eda/sentiment_analysis.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=self.data['sentiment'], palette='coolwarm')
# neutral     934914
# positive    341178
# negative    131236
# Name: sentiment, dtype: int64
#
# Common Keywords:
# /mnt/d/tutorial/10x/tasks/task_1/financial-news-stock-analysis/src/eda/sentiment_analysis.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(keywords), palette='magma')
# [('to', 402598), ('of', 269712), ('on', 244675), ('for', 238531), ('in', 219603), ('the', 209980), ('stocks', 159102), ('vs', 138801), ('eps', 127403), ('from', 120601)]

# %%
# Perform Time Series Analysis
time_series_analyzer = TimeSeriesAnalysis(cleaned_data)
print("\nPublication Frequency Over Time:")
print(time_series_analyzer.analyze_publication_frequency())
print("\nPublisher Contributions:")
print(time_series_analyzer.analyze_publisher_contributions())
# Out:
# Publication Frequency Over Time:
# date
# 2009-02-14 00:00:00+00:00      1
# 2009-02-15 00:00:00+00:00      0
# 2009-02-16 00:00:00+00:00      0
# 2009-02-17 00:00:00+00:00      0
# 2009-02-18 00:00:00+00:00      0
#                             ...
# 2020-06-07 00:00:00+00:00     25
# 2020-06-08 00:00:00+00:00    765
# 2020-06-09 00:00:00+00:00    803
# 2020-06-10 00:00:00+00:00    807
# 2020-06-11 00:00:00+00:00    544
# Freq: D, Length: 4136, dtype: int64
#
# Publisher Contributions:
# /mnt/d/tutorial/10x/tasks/task_1/financial-news-stock-analysis/src/eda/time_series_analysis.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=publisher_contributions.index, y=publisher_contributions.values, palette='plasma')
# publisher
# 47ertrends                       18
# AARP                              7
# ABNNewswire                      13
# Aakin                             5
# Aaron Jackson.Ed                 16
#                               ...
# vic@forextraininggroup.com        1
# vishwanath@benzinga.com        1830
# vivek.proactive@gmail.com       120
# wallstreet1928                    8
# webmaster                     20313
# Name: headline, Length: 1034, dtype: int64
