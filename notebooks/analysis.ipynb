# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../src')))
from data.data_loader import DataLoader

# %%
data_loader = DataLoader('../data/yfinance_data/TSLA_historical_data.csv')

data = data_loader.load_data()

# %%
from indicators.technical_indicators import TechnicalIndicators

# Initialize the TechnicalIndicators with the loaded data
indicators = TechnicalIndicators(data)

# Calculate Moving Averages, RSI, and MACD
indicators.calculate_moving_averages()
indicators.calculate_rsi()
indicators.calculate_macd()

# %%
from metrics.financial_metrics import FinancialMetrics

# Initialize FinancialMetrics with the data
metrics = FinancialMetrics(data)

# Calculate the Sharpe Ratio
sharpe_ratio = metrics.calculate_sharpe_ratio()
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
# Out:
# Sharpe Ratio: 0.06

# %%
from analysis.visualizer import Visualizer

# Initialize the Visualizer with the data
visualizer = Visualizer(data)

# Plot the data and indicators
visualizer.plot_moving_averages()
visualizer.plot_rsi()
visualizer.plot_macd()
